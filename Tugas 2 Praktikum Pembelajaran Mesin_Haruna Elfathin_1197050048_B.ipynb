# %%
import pandas as pd
import numpy as np

# %%
path = r"C:\Users\Elfathin\OneDrive\Documents\dataset\country_wise_latest.csv"
df = pd.read_csv(path)

# %%
df.head(10)
# Out:
#         Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0          Afghanistan      36263    1269      25198    9796        106
# 1              Albania       4880     144       2745    1991        117
# 2              Algeria      27973    1163      18837    7973        616
# 3              Andorra        907      52        803      52         10
# 4               Angola        950      41        242     667         18
# 5  Antigua and Barbuda         86       3         65      18          4
# 6            Argentina     167416    3059      72575   91782       4890
# 7              Armenia      37390     711      26665   10014         73
# 8            Australia      15303     167       9311    5825        368
# 9              Austria      20558     713      18246    1599         86
#
#    New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0          10             18                3.50                  69.49
# 1           6             63                2.95                  56.25
# 2           8            749                4.16                  67.34
# 3           0              0                5.73                  88.53
# 4           1              0                4.32                  25.47
# 5           0              5                3.49                  75.58
# 6         120           2057                1.83                  43.35
# 7           6            187                1.90                  71.32
# 8           6            137                1.09                  60.84
# 9           1             37                3.47                  88.75
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# 1                    5.25                 4171            709
# 2                    6.17                23691           4282
# 3                    6.48                  884             23
# 4                   16.94                  749            201
# 5                    4.62                   76             10
# 6                    4.21               130774          36642
# 7                    2.67                34981           2409
# 8                    1.79                12428           2875
# 9                    3.91                19743            815
#
#    1 week % increase             WHO Region
# 0               2.07  Eastern Mediterranean
# 1              17.00                 Europe
# 2              18.07                 Africa
# 3               2.60                 Europe
# 4              26.84                 Africa
# 5              13.16               Americas
# 6              28.02               Americas
# 7               6.89                 Europe
# 8              23.13        Western Pacific
# 9               4.13                 Europe

# %%
print(df.dtypes)
# Out:
# Country/Region             object
# Confirmed                   int64
# Deaths                      int64
# Recovered                   int64
# Active                      int64
# New cases                   int64
# New deaths                  int64
# New recovered               int64
# Deaths / 100 Cases        float64
# Recovered / 100 Cases     float64
# Deaths / 100 Recovered    float64
# Confirmed last week         int64
# 1 week change               int64
# 1 week % increase         float64
# WHO Region                 object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country/Region          187 non-null    object
#  1   Confirmed               187 non-null    int64
#  2   Deaths                  187 non-null    int64
#  3   Recovered               187 non-null    int64
#  4   Active                  187 non-null    int64
#  5   New cases               187 non-null    int64
#  6   New deaths              187 non-null    int64
#  7   New recovered           187 non-null    int64
#  8   Deaths / 100 Cases      187 non-null    float64
#  9   Recovered / 100 Cases   187 non-null    float64
#  10  Deaths / 100 Recovered  187 non-null    float64
#  11  Confirmed last week     187 non-null    int64
#  12  1 week change           187 non-null    int64
#  13  1 week % increase       187 non-null    float64
#  14  WHO Region              187 non-null    object
# dtypes: float64(4), int64(9), object(2)
# memory usage: 22.0+ KB

# %%
df.describe()
# Out:
#           Confirmed         Deaths     Recovered        Active     New cases  \
# count  1.870000e+02     187.000000  1.870000e+02  1.870000e+02    187.000000
# mean   8.813094e+04    3497.518717  5.063148e+04  3.400194e+04   1222.957219
# std    3.833187e+05   14100.002482  1.901882e+05  2.133262e+05   5710.374790
# min    1.000000e+01       0.000000  0.000000e+00  0.000000e+00      0.000000
# 25%    1.114000e+03      18.500000  6.265000e+02  1.415000e+02      4.000000
# 50%    5.059000e+03     108.000000  2.815000e+03  1.600000e+03     49.000000
# 75%    4.046050e+04     734.000000  2.260600e+04  9.149000e+03    419.500000
# max    4.290259e+06  148011.000000  1.846641e+06  2.816444e+06  56336.000000
#
#         New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# count   187.000000     187.000000          187.000000             187.000000
# mean     28.957219     933.812834            3.019519              64.820535
# std     120.037173    4197.719635            3.454302              26.287694
# min       0.000000       0.000000            0.000000               0.000000
# 25%       0.000000       0.000000            0.945000              48.770000
# 50%       1.000000      22.000000            2.150000              71.320000
# 75%       6.000000     221.000000            3.875000              86.885000
# max    1076.000000   33728.000000           28.560000             100.000000
#
#        Deaths / 100 Recovered  Confirmed last week  1 week change  \
# count                  187.00         1.870000e+02     187.000000
# mean                      inf         7.868248e+04    9448.459893
# std                       NaN         3.382737e+05   47491.127684
# min                      0.00         1.000000e+01     -47.000000
# 25%                      1.45         1.051500e+03      49.000000
# 50%                      3.62         5.020000e+03     432.000000
# 75%                      6.44         3.708050e+04    3172.000000
# max                       inf         3.834677e+06  455582.000000
#
#        1 week % increase
# count         187.000000
# mean           13.606203
# std            24.509838
# min            -3.840000
# 25%             2.775000
# 50%             6.890000
# 75%            16.855000
# max           226.320000

# %%
df.describe(include='all')
# Out:
#        Country/Region     Confirmed         Deaths     Recovered  \
# count             187  1.870000e+02     187.000000  1.870000e+02
# unique            187           NaN            NaN           NaN
# top       Afghanistan           NaN            NaN           NaN
# freq                1           NaN            NaN           NaN
# mean              NaN  8.813094e+04    3497.518717  5.063148e+04
# std               NaN  3.833187e+05   14100.002482  1.901882e+05
# min               NaN  1.000000e+01       0.000000  0.000000e+00
# 25%               NaN  1.114000e+03      18.500000  6.265000e+02
# 50%               NaN  5.059000e+03     108.000000  2.815000e+03
# 75%               NaN  4.046050e+04     734.000000  2.260600e+04
# max               NaN  4.290259e+06  148011.000000  1.846641e+06
#
#               Active     New cases   New deaths  New recovered  \
# count   1.870000e+02    187.000000   187.000000     187.000000
# unique           NaN           NaN          NaN            NaN
# top              NaN           NaN          NaN            NaN
# freq             NaN           NaN          NaN            NaN
# mean    3.400194e+04   1222.957219    28.957219     933.812834
# std     2.133262e+05   5710.374790   120.037173    4197.719635
# min     0.000000e+00      0.000000     0.000000       0.000000
# 25%     1.415000e+02      4.000000     0.000000       0.000000
# 50%     1.600000e+03     49.000000     1.000000      22.000000
# 75%     9.149000e+03    419.500000     6.000000     221.000000
# max     2.816444e+06  56336.000000  1076.000000   33728.000000
#
#         Deaths / 100 Cases  Recovered / 100 Cases  Deaths / 100 Recovered  \
# count           187.000000             187.000000                  187.00
# unique                 NaN                    NaN                     NaN
# top                    NaN                    NaN                     NaN
# freq                   NaN                    NaN                     NaN
# mean              3.019519              64.820535                     inf
# std               3.454302              26.287694                     NaN
# min               0.000000               0.000000                    0.00
# 25%               0.945000              48.770000                    1.45
# 50%               2.150000              71.320000                    3.62
# 75%               3.875000              86.885000                    6.44
# max              28.560000             100.000000                     inf
#
#         Confirmed last week  1 week change  1 week % increase WHO Region
# count          1.870000e+02     187.000000         187.000000        187
# unique                  NaN            NaN                NaN          6
# top                     NaN            NaN                NaN     Europe
# freq                    NaN            NaN                NaN         56
# mean           7.868248e+04    9448.459893          13.606203        NaN
# std            3.382737e+05   47491.127684          24.509838        NaN
# min            1.000000e+01     -47.000000          -3.840000        NaN
# 25%            1.051500e+03      49.000000           2.775000        NaN
# 50%            5.020000e+03     432.000000           6.890000        NaN
# 75%            3.708050e+04    3172.000000          16.855000        NaN
# max            3.834677e+06  455582.000000         226.320000        NaN

# %%
df.fillna(0)
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0            10             18                3.50                  69.49
# 1             6             63                2.95                  56.25
# 2             8            749                4.16                  67.34
# 3             0              0                5.73                  88.53
# 4             1              0                4.32                  25.47
# ..          ...            ...                 ...                    ...
# 182           2              0                0.73                  35.33
# 183           0              0               10.00                  80.00
# 184           4             36               28.56                  49.26
# 185           1            465                3.08                  61.84
# 186           2             24                1.33                  20.04
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                      5.04                35526            737
# 1                      5.25                 4171            709
# 2                      6.17                23691           4282
# 3                      6.48                  884             23
# 4                     16.94                  749            201
# ..                      ...                  ...            ...
# 182                    2.08                 8916           1705
# 183                   12.50                   10              0
# 184                   57.98                 1619             72
# 185                    4.97                 3326           1226
# 186                    6.64                 1713            991
#
#      1 week % increase             WHO Region
# 0                 2.07  Eastern Mediterranean
# 1                17.00                 Europe
# 2                18.07                 Africa
# 3                 2.60                 Europe
# 4                26.84                 Africa
# ..                 ...                    ...
# 182              19.12  Eastern Mediterranean
# 183               0.00                 Africa
# 184               4.45  Eastern Mediterranean
# 185              36.86                 Africa
# 186              57.85                 Africa
#
# [187 rows x 15 columns]

# %%
df.corr()
# Out:
#                         Confirmed    Deaths  Recovered    Active  New cases  \
# Confirmed                1.000000  0.934698   0.906377  0.927018   0.909720
# Deaths                   0.934698  1.000000   0.832098  0.871586   0.806975
# Recovered                0.906377  0.832098   1.000000  0.682103   0.818942
# Active                   0.927018  0.871586   0.682103  1.000000   0.851190
# New cases                0.909720  0.806975   0.818942  0.851190   1.000000
# New deaths               0.871683  0.814161   0.820338  0.781123   0.935947
# New recovered            0.859252  0.765114   0.919203  0.673887   0.914765
# Deaths / 100 Cases       0.063550  0.251565   0.048438  0.054380   0.020104
# Recovered / 100 Cases   -0.064815 -0.114529   0.026610 -0.132618  -0.078666
# Deaths / 100 Recovered   0.025175  0.169006  -0.027277  0.058386  -0.011637
# Confirmed last week      0.999127  0.939082   0.899312  0.931459   0.896084
# 1 week change            0.954710  0.855330   0.910013  0.847642   0.959993
# 1 week % increase       -0.010161 -0.034708  -0.013697 -0.003752   0.030791
#
#                         New deaths  New recovered  Deaths / 100 Cases  \
# Confirmed                 0.871683       0.859252            0.063550
# Deaths                    0.814161       0.765114            0.251565
# Recovered                 0.820338       0.919203            0.048438
# Active                    0.781123       0.673887            0.054380
# New cases                 0.935947       0.914765            0.020104
# New deaths                1.000000       0.889234            0.060399
# New recovered             0.889234       1.000000            0.017090
# Deaths / 100 Cases        0.060399       0.017090            1.000000
# Recovered / 100 Cases    -0.062792      -0.024293           -0.168920
# Deaths / 100 Recovered   -0.020750      -0.023340            0.334594
# Confirmed last week       0.862118       0.839692            0.069894
# 1 week change             0.894915       0.954321            0.015095
# 1 week % increase         0.025293       0.032662           -0.134534
#
#                         Recovered / 100 Cases  Deaths / 100 Recovered  \
# Confirmed                           -0.064815                0.025175
# Deaths                              -0.114529                0.169006
# Recovered                            0.026610               -0.027277
# Active                              -0.132618                0.058386
# New cases                           -0.078666               -0.011637
# New deaths                          -0.062792               -0.020750
# New recovered                       -0.024293               -0.023340
# Deaths / 100 Cases                  -0.168920                0.334594
# Recovered / 100 Cases                1.000000               -0.295381
# Deaths / 100 Recovered              -0.295381                1.000000
# Confirmed last week                 -0.064600                0.030460
# 1 week change                       -0.063013               -0.013763
# 1 week % increase                   -0.394254               -0.049083
#
#                         Confirmed last week  1 week change  1 week % increase
# Confirmed                          0.999127       0.954710          -0.010161
# Deaths                             0.939082       0.855330          -0.034708
# Recovered                          0.899312       0.910013          -0.013697
# Active                             0.931459       0.847642          -0.003752
# New cases                          0.896084       0.959993           0.030791
# New deaths                         0.862118       0.894915           0.025293
# New recovered                      0.839692       0.954321           0.032662
# Deaths / 100 Cases                 0.069894       0.015095          -0.134534
# Recovered / 100 Cases             -0.064600      -0.063013          -0.394254
# Deaths / 100 Recovered             0.030460      -0.013763          -0.049083
# Confirmed last week                1.000000       0.941448          -0.015247
# 1 week change                      0.941448       1.000000           0.026594
# 1 week % increase                 -0.015247       0.026594           1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

korelasi = df.corr()
plt.figure(figsize=(15, 10))
sns.heatmap(korelasi[(korelasi >= 0.5) | (korelasi <= -0.4)], cmap='viridis', vmax=1.0, vmin=-1.0, linewidths=0.1, 
            annot=True, annot_kws={"size": 8}, square=True).set_title('Korelasi Antar Variabel')
plt.show()

# %%
case_total = df.groupby("Country/Region")["Confirmed"].sum().sort_values()
case_total.plot(kind="barh", fontsize=10, figsize=(8,40), title='Kasus terkonfirmasi Positif COVID-19')
plt.show()

people_total = df.groupby("Country/Region")["Deaths"].sum().sort_values()
people_total.plot(kind="barh", fontsize=10, figsize=(8,40), title='Kasus meninggal disebabkan COVID-19')
plt.show()

recover_total = df.groupby("Country/Region")["Recovered"].sum().sort_values()
recover_total.plot(kind="barh", fontsize=10, figsize=(8,40), title='Kasus sembuh dari COVID-19')
plt.show()

# %%
sns.boxplot(df['Confirmed'])
# Out:
# C:\Users\Elfathin\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Confirmed'>

# %%
sns.boxplot(df['Deaths'])
# Out:
# C:\Users\Elfathin\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Deaths'>

# %%
sns.boxplot(df['Recovered'])
# Out:
# C:\Users\Elfathin\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Recovered'>

# %%
# Scatter plot
fig, ax = plt.subplots(figsize = (8,8))
ax.scatter(df['Confirmed'], df['Deaths'])

# x-axis label
ax.set_xlabel('Total Terkonfirmasi COVID-19')
 
# y-axis label
ax.set_ylabel('Total Pulih COVID-19')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 2>()
#       1 # Scatter plot
# ----> 2 fig, ax = plt.subplots(figsize = (8,8))
#       3 ax.scatter(df['Confirmed'], df['Deaths'])
#       5 # x-axis label
#
# NameError: name 'plt' is not defined

# %%
# !pip install Sastrawi
# Out:
# Requirement already satisfied: Sastrawi in c:\users\elfathin\appdata\local\programs\python\python310\lib\site-packages (1.0.1)

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\elfathin\appdata\local\programs\python\python310\lib\site-packages (3.7)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\elfathin\appdata\local\programs\python\python310\lib\site-packages (from nltk) (2022.3.2)
# Requirement already satisfied: tqdm in c:\users\elfathin\appdata\local\programs\python\python310\lib\site-packages (from nltk) (4.63.0)
# Requirement already satisfied: click in c:\users\elfathin\appdata\local\programs\python\python310\lib\site-packages (from nltk) (8.0.4)
# Requirement already satisfied: joblib in c:\users\elfathin\appdata\local\programs\python\python310\lib\site-packages (from nltk) (1.1.0)
# Requirement already satisfied: colorama in c:\users\elfathin\appdata\local\programs\python\python310\lib\site-packages (from click->nltk) (0.4.4)

# %%
import nltk #import library nltk
from nltk.tokenize import word_tokenize #import word_tokenize for tokenizing text into words 
from nltk.tokenize import sent_tokenize #import sent_tokenize for tokenizing paragraph into sentences
from nltk.stem.porter import PorterStemmer #import Porter Stemmer Algorithm 
from nltk.stem import WordNetLemmatizer #import WordNet lemmatizer 
from nltk.corpus import stopwords #import stopwords
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory #import Indonesian Stemmer
import re #import regular expression
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
#casefolding
def casefolding(s):
    new_str = s.lower()
    
    return new_str

text_data = "Rajin pangkal pandai. Hemat pangkal kaya. Usaha yang tiada henti, pasti akan membuahkan hasil yang baik."
casefolding(text_data)
# Out:
# 'rajin pangkal pandai. hemat pangkal kaya. usaha yang tiada henti, pasti akan membuahkan hasil yang baik.'

# %%
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package basque_grammars is already up-to-date!
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package biocreative_ppi is already up-to-date!
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package bllip_wsj_no_aux is already up-to-date!
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package book_grammars is already up-to-date!
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package brown_tei to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package brown_tei is already up-to-date!
# [nltk_data]    | Downloading package cess_cat to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cess_cat is already up-to-date!
# [nltk_data]    | Downloading package cess_esp to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cess_esp is already up-to-date!
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package city_database is already up-to-date!
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package comparative_sentences is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package comtrans to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package comtrans is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# [nltk_data]    | Downloading package conll2007 to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2007 is already up-to-date!
# [nltk_data]    | Downloading package crubadan to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package crubadan is already up-to-date!
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package dependency_treebank is already up-to-date!
# [nltk_data]    | Downloading package dolch to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package dolch is already up-to-date!
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package europarl_raw is already up-to-date!
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package extended_omw is already up-to-date!
# [nltk_data]    | Downloading package floresta to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package floresta is already up-to-date!
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package framenet_v15 is already up-to-date!
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package framenet_v17 is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package ieer to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ieer is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package indian to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package indian is already up-to-date!
# [nltk_data]    | Downloading package jeita to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package jeita is already up-to-date!
# [nltk_data]    | Downloading package kimmo to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package kimmo is already up-to-date!
# [nltk_data]    | Downloading package knbc to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package knbc is already up-to-date!
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package large_grammars is already up-to-date!
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package lin_thesaurus is already up-to-date!
# [nltk_data]    | Downloading package mac_morpho to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mac_morpho is already up-to-date!
# [nltk_data]    | Downloading package machado to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package machado is already up-to-date!
# [nltk_data]    | Downloading package masc_tagged to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package masc_tagged is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package moses_sample is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package mte_teip5 to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mte_teip5 is already up-to-date!
# [nltk_data]    | Downloading package mwa_ppdb to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mwa_ppdb is already up-to-date!
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package nombank.1.0 to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nombank.1.0 is already up-to-date!
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nonbreaking_prefixes is already up-to-date!
# [nltk_data]    | Downloading package nps_chat to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nps_chat is already up-to-date!
# [nltk_data]    | Downloading package omw to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package opinion_lexicon is already up-to-date!
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package panlex_swadesh is already up-to-date!
# [nltk_data]    | Downloading package paradigms to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package paradigms is already up-to-date!
# [nltk_data]    | Downloading package pe08 to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pe08 is already up-to-date!
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package perluniprops is already up-to-date!
# [nltk_data]    | Downloading package pil to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pil is already up-to-date!
# [nltk_data]    | Downloading package pl196x to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pl196x is already up-to-date!
# [nltk_data]    | Downloading package porter_test to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package porter_test is already up-to-date!
# [nltk_data]    | Downloading package ppattach to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ppattach is already up-to-date!
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package problem_reports is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package product_reviews_1 is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package product_reviews_2 is already up-to-date!
# [nltk_data]    | Downloading package propbank to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package propbank is already up-to-date!
# [nltk_data]    | Downloading package pros_cons to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pros_cons is already up-to-date!
# [nltk_data]    | Downloading package ptb to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ptb is already up-to-date!
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package qc to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package qc is already up-to-date!
# [nltk_data]    | Downloading package reuters to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package reuters is already up-to-date!
# [nltk_data]    | Downloading package rslp to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package rslp is already up-to-date!
# [nltk_data]    | Downloading package rte to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package rte is already up-to-date!
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sample_grammars is already up-to-date!
# [nltk_data]    | Downloading package semcor to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package semcor is already up-to-date!
# [nltk_data]    | Downloading package senseval to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package senseval is already up-to-date!
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sentence_polarity is already up-to-date!
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sentiwordnet is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sinica_treebank is already up-to-date!
# [nltk_data]    | Downloading package smultron to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package smultron is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package spanish_grammars is already up-to-date!
# [nltk_data]    | Downloading package state_union to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package state_union is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package subjectivity is already up-to-date!
# [nltk_data]    | Downloading package swadesh to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package swadesh is already up-to-date!
# [nltk_data]    | Downloading package switchboard to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package switchboard is already up-to-date!
# [nltk_data]    | Downloading package tagsets to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package tagsets is already up-to-date!
# [nltk_data]    | Downloading package timit to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package timit is already up-to-date!
# [nltk_data]    | Downloading package toolbox to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package toolbox is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package udhr to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package udhr is already up-to-date!
# [nltk_data]    | Downloading package udhr2 to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package udhr2 is already up-to-date!
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package unicode_samples is already up-to-date!
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package universal_tagset is already up-to-date!
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package universal_treebanks_v20 is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package vader_lexicon is already up-to-date!
# [nltk_data]    | Downloading package verbnet to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package verbnet is already up-to-date!
# [nltk_data]    | Downloading package verbnet3 to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package verbnet3 is already up-to-date!
# [nltk_data]    | Downloading package webtext to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package webtext is already up-to-date!
# [nltk_data]    | Downloading package wmt15_eval to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wmt15_eval is already up-to-date!
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package word2vec_sample is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package ycoe to
# [nltk_data]    |     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ycoe is already up-to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# True

# %%
sent_tokenize(casefolding(text_data))
# Out:
# ['rajin pangkal pandai.',
#  'hemat pangkal kaya.',
#  'usaha yang tiada henti, pasti akan membuahkan hasil yang baik.']

# %%
def word_tokenization(s):
    tokens = word_tokenize(s)

    return tokens
    
word_tokenization(text_data)
# Out:
# ['Rajin',
#  'pangkal',
#  'pandai',
#  '.',
#  'Hemat',
#  'pangkal',
#  'kaya',
#  '.',
#  'Usaha',
#  'yang',
#  'tiada',
#  'henti',
#  ',',
#  'pasti',
#  'akan',
#  'membuahkan',
#  'hasil',
#  'yang',
#  'baik',
#  '.']

# %%
#Stemming Indonesian
def stemmingIndo(str):
    factory = StemmerFactory()
    stemmer = factory.create_stemmer()
    return stemmer.stem(str)

stemmingIndo(text_data)
# Out:
# 'rajin pangkal pandai hemat pangkal kaya usaha yang tiada henti pasti akan buah hasil yang baik'

# %%
word_tokenization(stemmingIndo(text_data))
# Out:
# ['rajin',
#  'pangkal',
#  'pandai',
#  'hemat',
#  'pangkal',
#  'kaya',
#  'usaha',
#  'yang',
#  'tiada',
#  'henti',
#  'pasti',
#  'akan',
#  'buah',
#  'hasil',
#  'yang',
#  'baik']

# %%
factory = StopWordRemoverFactory()
stopword = factory.create_stop_word_remover()
stopword.remove(text_data)
# Out:
# 'Rajin pangkal pandai. Hemat pangkal kaya. Usaha tiada henti, akan membuahkan hasil baik.'

# %%
factory = StopWordRemoverFactory()
stopword = factory.create_stop_word_remover()
stopword.remove(text_data)
# Out:
# 'Rajin pangkal pandai. Hemat pangkal kaya. Usaha tiada henti, akan membuahkan hasil baik.'

# %%
#Stemming English
def stemmingEnglish(str):
    porter_stemmer = PorterStemmer()
    words = word_tokenize(str)
    result = list()
    for word in words:
        result.append(porter_stemmer.stem(word))
        
    return ' '.join(result)

text_data = "We are very, very small. But we are profoundly capable of very, very big things"
stemmingEnglish(text_data)
# Out:
# 'we are veri , veri small . but we are profoundli capabl of veri , veri big thing'

# %%
porter_stemmer = PorterStemmer()

word_data = "Life becomes better when you stop thinking about what other people think Play your own game"
# First Word tokenization
nltk_tokens = nltk.word_tokenize(word_data)
#Next find the roots of the word
for w in nltk_tokens:
       print("Actual: %s  Stem: %s"  % (w,porter_stemmer.stem(w)))
# Out:
# Actual: Life  Stem: life
# Actual: becomes  Stem: becom
# Actual: better  Stem: better
# Actual: when  Stem: when
# Actual: you  Stem: you
# Actual: stop  Stem: stop
# Actual: thinking  Stem: think
# Actual: about  Stem: about
# Actual: what  Stem: what
# Actual: other  Stem: other
# Actual: people  Stem: peopl
# Actual: think  Stem: think
# Actual: Play  Stem: play
# Actual: your  Stem: your
# Actual: own  Stem: own
# Actual: game  Stem: game

# %%
nltk.download('wordnet')
wordnet_lemmatizer = WordNetLemmatizer()

word_data = "Life becomes better when you stop thinking about what other people think Play your own game"
nltk_tokens = nltk.word_tokenize(word_data)
for w in nltk_tokens:
       print ("Actual: %s  Lemma: %s"  % (w,wordnet_lemmatizer.lemmatize(w)))
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Actual: Life  Lemma: Life
# Actual: becomes  Lemma: becomes
# Actual: better  Lemma: better
# Actual: when  Lemma: when
# Actual: you  Lemma: you
# Actual: stop  Lemma: stop
# Actual: thinking  Lemma: thinking
# Actual: about  Lemma: about
# Actual: what  Lemma: what
# Actual: other  Lemma: other
# Actual: people  Lemma: people
# Actual: think  Lemma: think
# Actual: Play  Lemma: Play
# Actual: your  Lemma: your
# Actual: own  Lemma: own
# Actual: game  Lemma: game

# %%
#remove digit from string
def removeDigit(str):
    new_string =  re.sub(r"[0-9]", " ", str)
    return new_string

text_data = "Saya lahir tanggal 11 Oktober 2001"
removeDigit(text_data)
# Out:
# 'Saya lahir tanggal    Oktober     '

# %%
#pos tagging
nltk.download('averaged_perceptron_tagger')
def postag(str):
    tok_sentence = nltk.word_tokenize(str)
    tagged_sentence = nltk.pos_tag(tok_sentence)
    return tagged_sentence

text_data = "It originated from the idea that there are readers who prefer learning new skills from the comforts of their drawing rooms"
postag(text_data)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Elfathin\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [('It', 'PRP'),
#  ('originated', 'VBD'),
#  ('from', 'IN'),
#  ('the', 'DT'),
#  ('idea', 'NN'),
#  ('that', 'IN'),
#  ('there', 'EX'),
#  ('are', 'VBP'),
#  ('readers', 'NNS'),
#  ('who', 'WP'),
#  ('prefer', 'VBP'),
#  ('learning', 'VBG'),
#  ('new', 'JJ'),
#  ('skills', 'NNS'),
#  ('from', 'IN'),
#  ('the', 'DT'),
#  ('comforts', 'NNS'),
#  ('of', 'IN'),
#  ('their', 'PRP$'),
#  ('drawing', 'NN'),
#  ('rooms', 'NNS')]

# %%
import re, string, unicodedata

def cleaning(str):
    #remove non-ascii
    str = unicodedata.normalize('NFKD', str).encode('ascii', 'ignore').decode('utf-8', 'ignore')
    #remove URLs
    str = re.sub(r'(?i)\b((?:https?://|www\d{0,3}[.]|[a-z0-9.\-]+[.][a-z]{2,4}/)(?:[^\s()<>]+|\(([^\s()<>]+|(\([^\s()<>]+\)))*\))+(?:\(([^\s()<>]+|(\([^\s()<>]+\)))*\)|[^\s`!()\[\]{};:\'".,<>?«»“”‘’]))', '', str)
    #remove punctuations
    str = re.sub(r'[^\w]|_',' ',str)
    #remove digit from string
    str = re.sub("\S*\d\S*", "", str).strip()
    #remove digit or numbers
    str = re.sub(r"\b\d+\b", " ", str)
    #to lowercase
    str = str.lower()
    #Remove additional white spaces
    str = re.sub('[\s]+', ' ', str)
    
    return str

str = "Copyright © 2008 John Wiley & Sons, Ltd. adalah ini https://www.analyticsvidhya.com/blog/2015/10/6-practices-enhance-performance-text-classification-model/"
print(cleaning(str))
# Out:
# copyright john wiley sons ltd adalah ini

# %%
text= open(r"C:\Users\Elfathin\Downloads\IndonesiaTangguhLawanCovid.txt", encoding='utf-8')
txt = text.read()

# %%
clean_txt = cleaning(txt)

# %%
stop = stopword.remove(clean_txt)
print(stop)
# Out:
# pertimbangkan melakukan hal berikut apa yg terjadi india terjadi indonesia tercinta perusahaan perkantoran pabrik memaksimalkan wfh kala kasus harian naik terus sebagian tetap wfo perketat prokes khususnya terkait upgrade masker memaksimalkan ventilasi pelarangan makan bersama nyawa karyawan minimal kesehatan jangka panjang ada tangan para manajer direktur lindungi aset paling berharga bisnis covid long covid batalkan rencana pembelajaran tatap muka ptm nasional wabah dianggap terkendali kalaupun kebijakan ptm dibatalkan jangan kirim anak turut kecuali yakin prokes ditegakkan mitigasi disiapkan ada kasus positif lingkungan sekolah tentunya siap segala konsekuensi pilihan covid anak berbahaya menyebabkan long covid walaupun otg telah dinyatakan sembuh segera buka vaksinasi seluas luasnya semudah mudahnya usia tahun atas prioritaskan dosis pertama sebanyak banyaknya orang menggunakan vaksin astrazeneca yg terbukti lebih efektif mencegah rawat inap rs hapuskan syarat surat domisili cukup ktp daerah manapun segeralah vaksin mendapatkan kesempatan apapun jenis vaksinnya akan membantu mencegah fasyankes kolaps jumlah kasus aktif terus meninggi sebisa mungkin rumah lakukan aktivitas sehari hari belanja via daring lalu perketat prokes rumah memaksimalkan ventilasi udara ruangan memakai masker seruangan anggota keluarga yg rutin aktivitas luar rumah menghindari makan bersama anggota keluarga tersebut ada mengalami gejala batuk demam pilek nyeri tenggorok sesak nafas wajib pakai masker walaupun sedang rumah hindari kontak fisik anggota keluarga lainnya kegiatan apapun yg dilakukan bersama lebih dari orang yg tinggal serumah usahakan dilakukan luar ruangan ruang ventilasinya betul betul maksimal misal dinding sisi terbuka kalau harus ruangan usahakan semua jendela dibuka sistem pendingin ruangan disetel memaksimalkan sirkulasi udara luar tentunya prokes seperti masker jaga jarak tetap ditegakkan upgrade masker hindari memakai masker kain pakailah minimal masker bedah didobel masker kain usahakan menggunakan masker harga per maskernya cukup murah pakai masker benar menutup hidung mulut tepian masker menempel rapat wajah apapun varian virusnya mencegah droplet yg melayang udara masuk tubuh adalah cara terbaik melawan covid kalau harus makan luar rumah hindari makan bagian indoor restoran situasi sangat beresiko terjadi penularan seandainya salah satu pelanggan karyawan situ positif covid otg cari tempat duduk outdoor minimal yg semi terbuka ventilasinya bagus pertimbangkan makanan dibungkus untuk dimakan kendaraan taman lokasi yg lebih sepi terbuka aman maksimalkan jumlah armada angkutan umum batasi kapasitas buka jendela memungkinkan larang penggunaan masker kain kendaraan minimal masker bedah didobel masker kain masker jangan hindari prosedur tes pelacakan isolasi perawatan nakes menyelamatkan masyarakat bukan mengcovidkan susah lelah lebih lebih karena harus mempertaruhkan kesehatan nyawa mengurus masyarakat yg terkena covid hargailah patuhilah selalu ingat kalau tertular covid mungkin otg atau gejala ringan lalu sembuh sempurna lansia orang dewasa maupun anak yang mungkin tulari bisa sakit berkepanjangan bahkan meninggal kalau siap dengan konsekuensi dunia akhirat mengabaikan prokes selalu jagalah sempurnakan prokes anda mari bersama cegah makin banyaknya kluster perkantoran keluarga komunitas kita turut bertanggung jawab bisa berperan dalam pengendalian wabah menjaga keselamatan sesama info lebih lanjut id versi terkini tulisan bisa diakses di

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\Elfathin\AppData\Local\Programs\Python\Python310\python.exe

# %%
# !pip install some_package
# Out:
# Requirement already satisfied: some_package in c:\users\elfathin\appdata\local\programs\python\python310\lib\site-packages (0.1)

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\elfathin\appdata\local\programs\python\python310\lib\site-packages (1.8.1)
# Requirement already satisfied: pillow in c:\users\elfathin\appdata\local\programs\python\python310\lib\site-packages (from wordcloud) (9.0.1)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\elfathin\appdata\local\programs\python\python310\lib\site-packages (from wordcloud) (1.22.2)
# Requirement already satisfied: matplotlib in c:\users\elfathin\appdata\local\programs\python\python310\lib\site-packages (from wordcloud) (3.5.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\elfathin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\elfathin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\elfathin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\elfathin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (3.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\elfathin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\elfathin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (4.29.1)
# Requirement already satisfied: six>=1.5 in c:\users\elfathin\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

wordcloud = WordCloud(max_font_size=30, background_color="white").generate(stop)
plt.figure(figsize=(10,8))

'''plot wordcloud in matplotlib'''

plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
words_in_article = stop.split()

# %%
import collections
import itertools

# Create counter
counts_no_urls = collections.Counter(words_in_article)

counts_no_urls.most_common(15)
# Out:
# [('masker', 15),
#  ('yg', 9),
#  ('covid', 8),
#  ('prokes', 6),
#  ('lebih', 6),
#  ('rumah', 5),
#  ('memaksimalkan', 4),
#  ('makan', 4),
#  ('bersama', 4),
#  ('minimal', 4),
#  ('ruangan', 4),
#  ('keluarga', 4),
#  ('luar', 4),
#  ('hindari', 4),
#  ('kalau', 4)]

# %%
import pandas as pd

df_txt = pd.DataFrame(counts_no_urls.most_common(15), columns=['words', 'count'])
df_txt.head()
# Out:
#     words  count
# 0  masker     15
# 1      yg      9
# 2   covid      8
# 3  prokes      6
# 4   lebih      6

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(figsize=(5, 5))

# Plot horizontal bar graph
df_txt.sort_values(by='count').plot.barh(x='words',
                      y='count',
                      ax=ax,
                      color="blue")

ax.set_title("Kata yang sering banyak muncul dari artikel Indonesia Tangguh Lawan Covid")

plt.show()

# %%
import json
import os

with open(r'C:\Users\Elfathin\Downloads\contoh_json.jsonl', encoding='utf-8', errors='ignore') as json_file:
    json_list = list(json_file)

    i=0
for json_str in json_list:
    i += 1
    result = json.loads(json_str)
    text = format(result['summary']).replace('\s+','')
    clean_text = cleaning(text)
    stop_text = stopword.remove(clean_text)
    stem_text = stemmingIndo(stop_text)
    
    print("Teks Ke-",i)
    print("Teks JSON:", text)
    print("Teks Bersih:", clean_text)
    print("Teks tanpa stopwords:", stop_text)
    print("Teks setelah stemming:", stem_text)
    print()
# Out:
# Teks Ke- 1
# Teks JSON: [['Eman', 'Ahmed', 'Abd', 'El', 'Aty', 'memiliki', 'berat', 'badan', 'mencapai', '500', 'kilogram', 'sebelum', 'menjalankan', 'operasi', 'di', 'Mumbai', 'Maret', 'lalu', 'dimana', 'ia', 'mengurangi', 'seperlima', 'dari', 'berat', 'badannya', '.'], ['Abd', 'El', 'Aty', 'diberi', 'diet', 'cairan', 'khusus', 'selama', 'berada', 'di', 'India', 'yang', 'bertujuan', 'menurunkan', 'berat', 'badan', '.'], ['Kini', ',', 'berat', 'badannya', 'telah', 'turun', 'drastis', 'sebanyak', '323', 'kilogram', 'dalam', 'tiga', 'bulan', '.'], ['Sekarang', 'berat', 'badannya', 'tinggal', '176,6', 'kilogram', '.']]
# Teks Bersih: eman ahmed abd el aty memiliki berat badan mencapai kilogram sebelum menjalankan operasi di mumbai maret lalu dimana ia mengurangi seperlima dari berat badannya abd el aty diberi diet cairan khusus selama berada di india yang bertujuan menurunkan berat badan kini berat badannya telah turun drastis sebanyak kilogram dalam tiga bulan sekarang berat badannya tinggal kilogram
# Teks tanpa stopwords: eman ahmed abd el aty memiliki berat badan mencapai kilogram menjalankan operasi mumbai maret lalu ia mengurangi seperlima berat badannya abd el aty diberi diet cairan khusus selama berada india bertujuan menurunkan berat badan kini berat badannya turun drastis sebanyak kilogram tiga bulan sekarang berat badannya tinggal kilogram
# Teks setelah stemming: eman ahmed abd el aty milik berat badan capai kilogram jalan operasi mumbai maret lalu ia kurang lima berat badan abd el aty beri diet cair khusus lama ada india tuju turun berat badan kini berat badan turun drastis banyak kilogram tiga bulan sekarang berat badan tinggal kilogram
#
# Teks Ke- 2
# Teks JSON: [['Menteri', 'Pertahanan', 'Ryamizard', 'Ryacudu', 'menyambut', 'baik', 'usulan', 'pembelian', 'drone', 'dari', 'China', 'untuk', 'dikembangkan', 'di', 'Indonesia', '.'], ['Pesawat', 'tanpa', 'awak', 'itu', 'rencananya', 'digunakan', 'untuk', 'misi', 'pertahanan', ',', 'yaitu', 'mengawasi', 'daerah', 'perbatasan', '.'], ['"', 'Kita', 'atau', 'orang', 'China', ',', 'orang', 'manapun', ',', 'beli', 'pasti', 'dia', 'bedah', 'itu', ',', 'pelajari', '.'], ['Kita', 'juga', 'beli', 'sedikit', 'satu', 'atau', 'dua', ',', 'kemudian', 'kita', 'pelajari', 'untuk', 'menambah', 'kecanggihan', 'itu', '.'], ['Semuanya', 'begitu', ',', '"', 'ujar', 'Ryamizard', 'di', 'Bogor', ',', 'Kamis', '(', '27', '/', '7', ')', '.']]
# Teks Bersih: menteri pertahanan ryamizard ryacudu menyambut baik usulan pembelian drone dari china untuk dikembangkan di indonesia pesawat tanpa awak itu rencananya digunakan untuk misi pertahanan yaitu mengawasi daerah perbatasan kita atau orang china orang manapun beli pasti dia bedah itu pelajari kita juga beli sedikit satu atau dua kemudian kita pelajari untuk menambah kecanggihan itu semuanya begitu ujar ryamizard di bogor kamis
# Teks tanpa stopwords: menteri pertahanan ryamizard ryacudu menyambut baik usulan pembelian drone china dikembangkan indonesia pesawat awak rencananya digunakan misi pertahanan mengawasi daerah perbatasan orang china orang manapun beli dia bedah pelajari juga beli sedikit satu atau dua kemudian pelajari menambah kecanggihan semuanya ujar ryamizard bogor kamis
# Teks setelah stemming: menteri tahan ryamizard ryacudu sambut baik usul beli drone china kembang indonesia pesawat awak rencana guna misi tahan awas daerah batas orang china orang mana beli dia bedah ajar juga beli sedikit satu atau dua kemudian ajar tambah canggih semua ujar ryamizard bogor kamis
#
# Teks Ke- 3
# Teks JSON: [['Rumah', 'produksi', 'film', 'yang', 'dibintangi', 'Lindsay', 'Lohan', ',', 'Rachel', 'McAdams', 'dan', 'Amanda', 'Seyfried', 'ini', 'kemudian', 'memutuskan', 'akan', 'mengadaptasinya', 'untuk', 'dibuat', 'dalam', 'versi', 'musikal', '.'], ['Meski', 'sudah', 'hampir', '12', 'tahun', 'berlalu', ',', 'film', 'Mean', 'Girls', '\xa0', 'merupakan', 'salah', 'satu', 'film', 'remaja', 'sepanjang', 'masa', 'yang', 'sulit', 'untuk', 'dilupakan', '.'], ['Dijadwalkan', 'pementasan', 'musikal', 'dari', 'adaptasi', 'naskah', '\xa0', 'itu', 'akan', 'berlangsung', 'September', ',', 'tahun', 'depan', 'di', 'Washington', 'DC', '.']]
# Teks Bersih: rumah produksi film yang dibintangi lindsay lohan rachel mcadams dan amanda seyfried ini kemudian memutuskan akan mengadaptasinya untuk dibuat dalam versi musikal meski sudah hampir tahun berlalu film mean girls merupakan salah satu film remaja sepanjang masa yang sulit untuk dilupakan dijadwalkan pementasan musikal dari adaptasi naskah itu akan berlangsung september tahun depan di washington dc
# Teks tanpa stopwords: rumah produksi film dibintangi lindsay lohan rachel mcadams amanda seyfried kemudian memutuskan mengadaptasinya dibuat versi musikal meski hampir tahun berlalu film mean girls merupakan salah satu film remaja sepanjang masa sulit dilupakan dijadwalkan pementasan musikal adaptasi naskah akan berlangsung september tahun depan washington dc
# Teks setelah stemming: rumah produksi film bintang lindsay loh rachel mcadams amanda seyfried kemudian putus adaptasi buat versi musikal meski hampir tahun lalu film mean girls rupa salah satu film remaja panjang masa sulit lupa jadwal mentas musikal adaptasi naskah akan langsung september tahun depan washington dc
#
# Teks Ke- 4
# Teks JSON: [['Eggi', 'Sudjana', 'akhirnya', 'mendatangi', 'kantor', 'Bareskrim', 'Polri', ',', 'Jakarta', ',', 'Senin', '(', '18', '/', '9', ')', ',', 'untuk', 'memberikan', 'klarifikasi', 'terkait', 'pencatutan', 'namanya', 'di', 'struktur', 'organisasi', 'Saracen', '.'], ['Eggi', 'juga', 'menyebutkan', ',', 'ia', 'sama', 'sekali', 'tidak', 'mengenal', 'atau', 'terlibat', 'dalam', 'sindikat', 'penyebar', 'berita', 'palsu', 'tersebut', '.'], ['Eggi', 'mengaku', 'tidak', 'akan', 'datang', 'jika', 'kembali', 'dipanggil', 'menjadi', 'saksi', '.'], ['Menurutnya', ',', 'ia', 'tidak', 'bisa', 'memenuhi', 'panggilan', 'sebagai', 'saksi', 'karena', 'tidak', 'memiliki', 'hubungan', 'dengan', 'Saracen', '.']]
# Teks Bersih: eggi sudjana akhirnya mendatangi kantor bareskrim polri jakarta senin untuk memberikan klarifikasi terkait pencatutan namanya di struktur organisasi saracen eggi juga menyebutkan ia sama sekali tidak mengenal atau terlibat dalam sindikat penyebar berita palsu tersebut eggi mengaku tidak akan datang jika kembali dipanggil menjadi saksi menurutnya ia tidak bisa memenuhi panggilan sebagai saksi karena tidak memiliki hubungan dengan saracen
# Teks tanpa stopwords: eggi sudjana akhirnya mendatangi kantor bareskrim polri jakarta senin memberikan klarifikasi terkait pencatutan namanya struktur organisasi saracen eggi menyebutkan sama sekali mengenal terlibat sindikat penyebar berita palsu tersebut eggi mengaku akan datang kembali dipanggil menjadi saksi menurutnya tidak memenuhi panggilan saksi tidak memiliki hubungan saracen
# Teks setelah stemming: eggi sudjana akhir datang kantor bareskrim polri jakarta senin beri klarifikasi kait catut nama struktur organisasi saracen eggi sebut sama sekali kenal libat sindikat sebar berita palsu sebut eggi aku akan datang kembali panggil jadi saksi turut tidak penuh panggil saksi tidak milik hubung saracen
#
# Teks Ke- 5
# Teks JSON: [['Game', 'permainan', 'Kartu', 'Muslim', '.'], ['Menggunakan', 'basis', 'teknologi', 'Augmented', 'Reality', '(', 'AR', ')', ',', 'permainan', 'kartu', 'tersebut', 'memberikan', 'pengajaran', 'agama', 'kepada', 'anak-anak', '.'], ['Penggunaannya', 'cukup', 'sederhana', ',', 'kartu', 'berhologram', 'khusus', 'dipasarkan', 'dalam', 'satu', 'set', 'produk', ',', 'misalnya', 'dalam', 'seri', 'belajar', 'Wudhu', '.'], ['Untuk', 'menyajikan', 'konten', 'unik', 'di', 'dalamnya', ',', 'kartu', 'tersebut', 'dapat', 'disorot', 'menggunakan', 'kamera', 'dan', 'aplikasi', 'khusus', 'di', 'ponsel', 'Android', '.']]
# Teks Bersih: game permainan kartu muslim menggunakan basis teknologi augmented reality ar permainan kartu tersebut memberikan pengajaran agama kepada anak anak penggunaannya cukup sederhana kartu berhologram khusus dipasarkan dalam satu set produk misalnya dalam seri belajar wudhu untuk menyajikan konten unik di dalamnya kartu tersebut dapat disorot menggunakan kamera dan aplikasi khusus di ponsel android
# Teks tanpa stopwords: game permainan kartu muslim menggunakan basis teknologi augmented reality ar permainan kartu tersebut memberikan pengajaran agama anak anak penggunaannya cukup sederhana kartu berhologram khusus dipasarkan satu set produk misalnya seri belajar wudhu menyajikan konten unik dalamnya kartu tersebut disorot menggunakan kamera aplikasi khusus ponsel android
# Teks setelah stemming: game main kartu muslim guna basis teknologi augmented reality ar main kartu sebut beri ajar agama anak anak guna cukup sederhana kartu hologram khusus pasar satu set produk misal seri ajar wudhu saji konten unik dalam kartu sebut sorot guna kamera aplikasi khusus ponsel android
# Teks Ke- 6
# Teks JSON: [['Sebuah', 'lagu', 'misterius', 'mendadak', 'muncul', 'di', 'iTunes', 'akhir', 'pekan', 'lalu', '.'], ['Lagu', 'itu', 'berjudul', '\xa0', 'Behind', 'Me', ',', '\xa0', 'disebut', 'sebagai', 'karya', 'dari', 'seorang', 'artis', 'tak', 'terkenal', 'bernama', 'Guido', 'Dos', 'Santos', '.'], ['Lagu', 'itu', 'diperkenalkan', 'ke', 'iTunes', 'tanpa', 'keterangan', 'apa', 'pun', ',', 'lalu', 'dihapus', '.'], ['Gay', 'Times', 'melaporkan', ',', 'lagu', 'itu', 'sempat', 'membuat', 'tertarik', 'banyak', 'orang', '.'], ['Bahkan', 'ia', 'masuk', 'daftar', '50', 'besar', 'lagu', 'laris', '.']]
# Teks Bersih: sebuah lagu misterius mendadak muncul di itunes akhir pekan lalu lagu itu berjudul behind me disebut sebagai karya dari seorang artis tak terkenal bernama guido dos santos lagu itu diperkenalkan ke itunes tanpa keterangan apa pun lalu dihapus gay times melaporkan lagu itu sempat membuat tertarik banyak orang bahkan ia masuk daftar besar lagu laris
# Teks tanpa stopwords: sebuah lagu misterius mendadak muncul itunes akhir pekan lalu lagu berjudul behind me disebut karya seorang artis tak terkenal bernama guido dos santos lagu diperkenalkan itunes keterangan apa lalu dihapus gay times melaporkan lagu sempat membuat tertarik banyak orang bahkan masuk daftar besar lagu laris
# Teks setelah stemming: buah lagu misterius dadak muncul itunes akhir pekan lalu lagu judul behind me sebut karya orang artis tak kenal nama guido dos santos lagu kenal itunes terang apa lalu hapus gay times lapor lagu sempat buat tarik banyak orang bahkan masuk daftar besar lagu laris
#
# Teks Ke- 7
# Teks JSON: [['Kementerian', 'Sosial', 'sudah', 'menetapkan', 'waktu', 'permintaan', 'klasifikasi', 'pemilik', 'akun', 'Instagram', '@cakbudi_.'], ['Permintaan', 'penjelasan', 'atas', 'tudingan', 'penyelewengan', 'dana', 'dari', 'donatur', 'akan', 'berlangsung', 'di', 'Jakarta', '.'], ['Direktur', 'Jenderal', 'Pemberdayaan', 'Sosial', ',', 'Hartono', 'Laras', ',', 'mengatakan', 'lusa', '(', 'Kamis', '-', 'red', ')', 'Cak', 'Budi', 'kami', 'panggil', ' ', 'ke', 'Jakarta', 'untuk', 'memberikan', 'klarifikasi', 'mengenai', 'mekanisme', 'penggalangan', 'donasi', '.'], ['Sedangkan', 'Menteri', 'Sosial', 'Khofifah', 'Indar', 'Parawansa', 'meminta', 'pengumpul', 'sumbangan', 'dari', 'masyarakat', 'untuk', 'menjaga', 'amanah', '.']]
# Teks Bersih: kementerian sosial sudah menetapkan waktu permintaan klasifikasi pemilik akun instagram cakbudi permintaan penjelasan atas tudingan penyelewengan dana dari donatur akan berlangsung di jakarta direktur jenderal pemberdayaan sosial hartono laras mengatakan lusa kamis red cak budi kami panggil ke jakarta untuk memberikan klarifikasi mengenai mekanisme penggalangan donasi sedangkan menteri sosial khofifah indar parawansa meminta pengumpul sumbangan dari masyarakat untuk menjaga amanah
# Teks tanpa stopwords: kementerian sosial menetapkan waktu permintaan klasifikasi pemilik akun instagram cakbudi permintaan penjelasan atas tudingan penyelewengan dana donatur berlangsung jakarta direktur jenderal pemberdayaan sosial hartono laras mengatakan lusa kamis red cak budi panggil jakarta memberikan klarifikasi mengenai mekanisme penggalangan donasi menteri sosial khofifah indar parawansa meminta pengumpul sumbangan masyarakat menjaga amanah
# Teks setelah stemming: menteri sosial tetap waktu minta klasifikasi milik akun instagram cakbudi minta jelas atas tuding seleweng dana donatur langsung jakarta direktur jenderal daya sosial hartono laras kata lusa kamis red cak budi panggil jakarta beri klarifikasi kena mekanisme galang donasi menteri sosial khofifah indar parawansa minta kumpul sumbang masyarakat jaga amanah
#
# Teks Ke- 8
# Teks JSON: [['Menteri', 'Koordinator', 'Bidang', 'Perekonomian', 'Darmin', 'Nasution', 'memastikan', ',', 'barang', 'tak', 'berwujud', '(', 'intangible', 'goods', ')', 'yang', 'diperdagangkan', 'secara', 'elektronik', 'dari', 'luar', 'negeri', 'akan', 'dikenakan', 'bea', 'masuk', '.'], ['Adapun', 'contoh', 'barang', 'tak', 'berwujud', 'tersebut', ',', 'yaitu', 'buku', 'elektronik', '(', 'e', '-', 'book', ')', ',', 'piranti', 'lunak', ',', 'dan', 'barang', 'lainnya', 'yang', 'tak', 'memiliki', 'wujud', '.'], ['Kementerian', 'Keuangan', 'masih', 'terus', 'mengkaji', 'rencana', 'pengenaan', 'bea', 'masuk', 'terhadap', 'barang', 'tak', 'berwujud', 'tersebut', '.']]
# Teks Bersih: menteri koordinator bidang perekonomian darmin nasution memastikan barang tak berwujud intangible goods yang diperdagangkan secara elektronik dari luar negeri akan dikenakan bea masuk adapun contoh barang tak berwujud tersebut yaitu buku elektronik e book piranti lunak dan barang lainnya yang tak memiliki wujud kementerian keuangan masih terus mengkaji rencana pengenaan bea masuk terhadap barang tak berwujud tersebut
# Teks tanpa stopwords: menteri koordinator bidang perekonomian darmin nasution memastikan barang tak berwujud intangible goods diperdagangkan elektronik luar negeri dikenakan bea masuk adapun contoh barang tak berwujud tersebut buku elektronik e book piranti lunak barang lainnya tak memiliki wujud kementerian keuangan terus mengkaji rencana pengenaan bea masuk barang tak berwujud tersebut
# Teks setelah stemming: menteri koordinator bidang ekonomi darmin nasution pasti barang tak wujud intangible goods dagang elektronik luar negeri kena bea masuk adapun contoh barang tak wujud sebut buku elektronik e book piranti lunak barang lain tak milik wujud menteri uang terus kaji rencana kena bea masuk barang tak wujud sebut
#
# Teks Ke- 9
# Teks JSON: [['Layanan', 'Keamanan', 'Federal', 'Rusia', '(', 'FSB', ')', 'menyatakan', 'bahwa', '10', 'orang', 'tersebut', 'ditangkap', 'dengan', 'bantuan', 'dari', 'Tajikistan', 'dan', 'Kyrgyzstan', '.'], ['Mereka', 'berencana', 'menyerang', 'dengan', 'senjata', 'otomatis', 'dan', 'bom', 'rakitan', 'di', 'tempat', 'publik', 'Moskow', 'dan', 'St.', 'Petersburg', '.'], ['Ribuan', 'warga', 'Rusia', 'sendiri', 'sudah', 'bergabung', 'dengan', 'kelompok', 'anti', '-', 'Assad', 'di', 'Suriah', ',', 'menurut', 'Perdana', 'Menteri', 'Rusia', 'Dmitry', 'Medvedev', 'pada', 'awal', 'November', '.']]
# Teks Bersih: layanan keamanan federal rusia fsb menyatakan bahwa orang tersebut ditangkap dengan bantuan dari tajikistan dan kyrgyzstan mereka berencana menyerang dengan senjata otomatis dan bom rakitan di tempat publik moskow dan st petersburg ribuan warga rusia sendiri sudah bergabung dengan kelompok anti assad di suriah menurut perdana menteri rusia dmitry medvedev pada awal november
# Teks tanpa stopwords: layanan keamanan federal rusia fsb menyatakan orang tersebut ditangkap bantuan tajikistan kyrgyzstan berencana menyerang senjata otomatis bom rakitan tempat publik moskow st petersburg ribuan warga rusia sendiri bergabung kelompok anti assad suriah perdana menteri rusia dmitry medvedev awal november
# Teks setelah stemming: layan aman federal rusia fsb nyata orang sebut tangkap bantu tajikistan kyrgyzstan rencana serang senjata otomatis bom rakit tempat publik moskow st petersburg ribu warga rusia sendiri gabung kelompok anti assad suriah perdana menteri rusia dmitry medvedev awal november
#
# Teks Ke- 10
# Teks JSON: [['Taylor', 'Swift', 'dikabarkan', 'pernah', 'memberikan', 'rumah', 'dan', 'perlengkapan', 'bayi', 'kepada', 'salah', 'satu', 'penggemarnya', '.'], ['Hal', 'ini', 'dilihat', 'dari', 'unggahan', 'Stephanie', ',', 'salah', 'seorang', 'penggemar', 'dari', 'pelantun', 'lagu', '‘', 'Red’', 'ini', '.'], ['Stephanie', 'menyebutkan', 'bahwa', 'Swift', 'telah', 'mengubah', 'hidupnya', '.'], ['Stephanie', 'dibelikan', 'rumah', 'serta', 'perlengkapan', 'bayi', 'setelah', 'ia', 'menjadi', 'gelandangan', 'karena', 'suaminya', 'yang', 'dipecat', '.'], ['Saat', 'itu', ',', 'Stephanie', 'juga', 'sedang', 'mengandung', '8', 'bulan', '.']]
# Teks Bersih: taylor swift dikabarkan pernah memberikan rumah dan perlengkapan bayi kepada salah satu penggemarnya hal ini dilihat dari unggahan stephanie salah seorang penggemar dari pelantun lagu red ini stephanie menyebutkan bahwa swift telah mengubah hidupnya stephanie dibelikan rumah serta perlengkapan bayi setelah ia menjadi gelandangan karena suaminya yang dipecat saat itu stephanie juga sedang mengandung bulan
# Teks tanpa stopwords: taylor swift dikabarkan pernah memberikan rumah perlengkapan bayi salah satu penggemarnya dilihat unggahan stephanie salah seorang penggemar pelantun lagu red ini stephanie menyebutkan swift mengubah hidupnya stephanie dibelikan rumah perlengkapan bayi ia menjadi gelandangan suaminya dipecat itu stephanie sedang mengandung bulan
# Teks setelah stemming: taylor swift kabar pernah beri rumah lengkap bayi salah satu gemar lihat unggah stephanie salah orang gemar lantun lagu red ini stephanie sebut swift ubah hidup stephanie beli rumah lengkap bayi ia jadi gelandang suami pecat itu stephanie sedang kandung bulan
